# %%
#checking if Python version is correcct
# !python -V
# Out:
# Python 3.13.11

# %% [markdown]
# ### Downloading Libraries neccessary for the lab

# %%
# !pip install pandas
import pandas as pd # reads into the dataframe
pd.set_option('display.max_columns',None)
import numpy as np #import numpy librar
import re #Import library for regular expressions
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 1.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.5/9.7 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.7 MB 753.4 kB/s eta 0:00:12
#    --- ------------------------------------ 0.8/9.7 MB 753.4 kB/s eta 0:00:12
#    --- ------------------------------------ 0.8/9.7 MB 753.4 kB/s eta 0:00:12
#    --- ------------------------------------ 0.8/9.7 MB 753.4 kB/s eta 0:00:12
#    ----- ---------------------------------- 1.3/9.7 MB 629.7 kB/s eta 0:00:14
#    ----- ---------------------------------- 1.3/9.7 MB 629.7 kB/s eta 0:00:14
# ...

# %% [markdown]
# Download the data from IBM SERVER and read it into a pandas adatframe

# %%
recipes = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/recipes.csv")

print("Data read into dataframe!") # takes about 30 seconds
# Out:
# Data read into dataframe!

# %%
# !pip install fetch
# !pip install io
from js import fetch
import io

URL = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0103EN-SkillsNetwork/labs/Module%202/recipes.csv'
resp= await fetch(URL)
text = io.BytesIO((await resp.arrayBuffer()).to_py())

recipes=pd.read_csv(text)

print('Data read into dataframe')
# Out:
# ...
#   Using cached fetch-0.0.tar.gz (7.3 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [23 lines of output]
#   Traceback (most recent call last):
#     File "C:\Users\HP\anaconda3\envs\pytr\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 389, in <module>
#       main()
#       ~~~~^^
#     File "C:\Users\HP\anaconda3\envs\pytr\Lib\site-packages\pip\_vendor\pyproject_hooks\_in_process\_in_process.py", line 373, in main
#       json_out["return_val"] = hook(**hook_input["kwargs"])
#                                ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
# ...
