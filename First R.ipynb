# %% [markdown]
# # My first r

# %%
2*3 #multiplication
# Out:
# [1] 6

# %%
4-1 #subtraction
# Out:
# [1] 3

# %%
a<-1 # assigning 1 to variable a
a+2
# Out:
# [1] 3

# %%
df= data.frame(Emp_name= c("Jai", "David", "Micahel"),Job_role=c("Manager","Team Lead","Developer"))
print(df)
# Out:
#   Emp_name  Job_role
# 1      Jai   Manager
# 2    David Team Lead
# 3  Micahel Developer
